# %% [markdown]
# # HIV 2015 ORS – Impact Score Computation
#
# This notebook computes the Impact Score for HIV 2015 data from the ORS (2015_2017_2019) Excel file.

# %%
import pandas as pd
import numpy as np
import re
from typing import Optional
from IPython.display import display

# %% [markdown]
# ## Load HIV2015 Data

# %%
# Load the HIV2015 sheet from the ORS Excel file
file_path = "ORS (2015_2017_2019) copied 2025-7-5.xlsx"
sheet_name = "HIV2015"

main_df = pd.read_excel(file_path, sheet_name=sheet_name, header=None)

# %% [markdown]
# ## Fix Headers

# %%
# Extract header from row 2 (0-indexed)
new_header = main_df.iloc[2]
main_df = main_df.iloc[4:]  # Data starts from row 4
main_df.columns = new_header
main_df = main_df.reset_index(drop=True)

main_df.head()
# Out:
# 2         Country WHO Region Population              Geographical Region  \
# 0     Afghanistan        EMR   33736494  East, South and South-East Asia
# 1         Albania        EUR    2880703          Europe and Central Asia
# 2         Algeria        AFR   39871528     Middle East and North Africa
# 3  American Samoa        WPR      55537                              NaN
# 4         Andorra        EUR      78014                              NaN
#
# 2 WHO Group        DALY Adult DALYs Children DALYs Retention Rate  \
# 0         A   10752.548    9224.366       1528.182             72
# 1         A   98.495261    96.59686       1.898401             92
# 2         A  11586.0447    11055.12       530.9247             92
# 3         A   28.518669    25.84525       2.673419          97.14
# 4         A    83.36974    83.20017        0.16957          97.14
#
# 2 Retention Rate (ADULT)  ... All ages Children (0-14) Adults (15+)  Year NaN  \
# 0                     73  ...       92             100           92  2015 NaN
# 1                     92  ...       92              77           92  2015 NaN
# 2                     92  ...      100             NaN          NaN  2015 NaN
# 3                  97.14  ...       66             NaN          NaN  2015 NaN
# 4                  97.14  ...       85             100           85  2015 NaN
#
# 2 http://apps.who.int/gho/data/node.main.626?lang=en  \
# 0                                        Afghanistan
# 1                                            Albania
# 2                                            Algeria
# 3                                            Andorra
# 4                                             Angola
#
# 2 Estimated antiretroviral therapy coverage among people living with HIV (%)  \
# 0                                           5 [3-12]
# 1                                            No data
# 2                                        90 [70->95]
# 3                                High-income country
# 4                                         29 [20-40]
#
# 2 Reported number of people receiving antiretroviral therapy Cleaned coverage  \
# 0                                                364                     0.05
# 1                                                423                      NaN
# 2                                              7 915                      0.9
# 3                                            No data                      NaN
# 4                                             90 204                     0.29
#
# 2 Cleaned number of people receiving antiretroviral therapy
# 0                                                364
# 1                                                423
# 2                                               7915
# 3                                                NaN
# 4                                              90204
#
# [5 rows x 84 columns]

# %%
main_df.columns
# Out:
# Index([                                                                   'Country',
#                                                                        'WHO Region',
#                                                                        'Population',
#                                                               'Geographical Region',
#                                                                         'WHO Group',
#                                                                              'DALY',
#                                                                       'Adult DALYs',
#                                                                    'Children DALYs',
#                                                                    'Retention Rate',
#                                                            'Retention Rate (ADULT)',
#                                                            'Retention Rate (CHILD)',
#                                                             '# Receiving Treatment',
#                                                               '# Needing Treatment',
#                                                              '% Treatment Coverage',
#                                                             '# Receiving Treatment',
#                                                               '# Needing Treatment',
#                                                              '% Treatment Coverage',
#                                                             '# Receiving Treatment',
#                                                               '# Needing Treatment',
#                                                              '% Treatment Coverage',
#                                            'Estimated adults (15+) living with HIV',
#                                         'Estimated children (0-14) living with HIV',
#                                       '# Adult Prevalent Cases Receiving Treatment',
#                                    '# Children Prevalent Cases Receiving Treatment',
#                                                                               '3TC',
#                                                                               'ABC',
#                                                                               'AZT',
#                                                                               'ddl',
#                                                                               'd4T',
#                                                                               'EFV',
#                                                                               'FTC',
#                                                                             'LPV/r',
#                                                                               'NVP',
#                                                                               'TDF',
#                                                                             'ATV/r',
#                                                          'Overall Treatment Impact',
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#                                        'average of 2013 antiretroviral treatment. ',
#                                                                                 nan,
#                                                                                 nan,
#                                 'Treatment Regimen Proportion and Efficacy Section',
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#              'impact =daly*treatment cover*x/(1-treatment cover*x)/number of drugs',
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#                                                                'Originator Company',
#                                                                           'Drug(s)',
#                                                                      'Final Impact',
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#                                                                       'Afghanistan',
#                                                                            9224.366,
#                                                                       'Afghanistan',
#                                                                            1528.182,
#                                                                                 nan,
#                                                                       'Afghanistan',
#                                                                                 500,
#                                                                                  26,
#                                                                                0.11,
#                                                                                 nan,
#                                                                                 nan,
#                                                                           'Country',
#                                                                          'All ages',
#                                                                   'Children (0-14)',
#                                                                      'Adults (15+)',
#                                                                              'Year',
#                                                                                 nan,
#                                'http://apps.who.int/gho/data/node.main.626?lang=en',
#        'Estimated antiretroviral therapy coverage among people living with HIV (%)',
#                        'Reported number of people receiving antiretroviral therapy',
#                                                                  'Cleaned coverage',
#                         'Cleaned number of people receiving antiretroviral therapy'],
#       dtype='object', name=2)

# %% [markdown]
# ## Helper Functions

# %%
def _col_idx(col_letters: str) -> int:
    """Convert Excel column letters to 0-based index."""
    col_letters = col_letters.strip().upper()
    n = 0
    for ch in col_letters:
        n = n * 26 + (ord(ch) - ord("A") + 1)
    return n - 1

def _to_float(x):
    """Robust float conversion."""
    if pd.isna(x):
        return np.nan
    if isinstance(x, str):
        s = x.strip().replace(",", "")
        if s == "" or s.lower() in ["nan", "no data"]:
            return np.nan
        if s.endswith("%"):
            try:
                return float(s[:-1]) / 100.0
            except:
                return np.nan
        try:
            return float(s)
        except:
            return np.nan
    try:
        return float(x)
    except:
        return np.nan

def _contains_drug(regimen_text, drug_token: str) -> bool:
    """Check if regimen contains the drug."""
    if pd.isna(regimen_text):
        return False
    reg = str(regimen_text).upper().replace(" ", "")
    tok = str(drug_token).upper().replace(" ", "")
    return tok != "" and tok in reg

def _regimen_size(regimen_text) -> float:
    """Count number of drugs in regimen."""
    if pd.isna(regimen_text):
        return 3.0
    s = str(regimen_text)
    parts = [p.strip() for p in re.split(r"\+", s) if p.strip() and p.strip().lower() != "nan"]
    if len(parts) >= 2:
        return float(len(parts))
    return 3.0

def _impact_term(base, const, coef1, var, coef2, denom) -> float:
    """Calculate impact term: base * const * coef1 * var * coef2 / (1 - const*coef1*var*coef2) / denom"""
    if denom == 0 or pd.isna(denom):
        return 0.0
    if any(pd.isna(v) for v in [base, const, coef1, var, coef2]):
        return 0.0
    prod = const * coef1 * var * coef2
    d = 1.0 - prod
    if d == 0:
        return 0.0
    return (base * prod / d) / denom

# %% [markdown]
# ## Load Regimen Tables and Constants

# %%
# Reload the raw data to access regimen tables
raw_df = pd.read_excel(file_path, sheet_name=sheet_name, header=None)

# Constants from column 41 (AO in Excel)
const_col = 41
AQ5 = _to_float(raw_df.iloc[4, const_col])   # Group A first-line adult
AQ6 = _to_float(raw_df.iloc[5, const_col])   # Group A second-line adult
AP5 = _to_float(raw_df.iloc[9, const_col])   # Group B first-line adult
AP6 = _to_float(raw_df.iloc[10, const_col])  # Group B second-line adult

# For children, use the same constants
AQ10 = AQ5
AQ11 = AQ6
AP10 = AP5
AP11 = AP6

print(f"Constants loaded:")
print(f"  Group A: First-line={AQ5}, Second-line={AQ6}")
print(f"  Group B: First-line={AP5}, Second-line={AP6}")
# Out:
# Constants loaded:
#   Group A: First-line=0.90835, Second-line=0.09165
#   Group B: First-line=0.89325, Second-line=0.10675

# %% [markdown]
# ## Compute Impact Score Function

# %%
def compute_impact_score_2015(
    main_df: pd.DataFrame,
    raw_df: pd.DataFrame,
    drug_name: str,
    output_col: Optional[str] = None,
    debug: bool = False,
    debug_show_first_n_rows: int = 3
):
    """
    Compute impact score using EXACT Excel formula.
    
    Formula: SUM(
        IF(drug in regimen, G*Q*AY/(1-Q*AY)/AX, 0) for adults,
        IF(drug in regimen, H*T*AZ/(1-T*AZ)/AX, 0) for children
    ) / (100/(100-I))
    
    Where:
    - AS (col 44) = Regimen name
    - AX (col 49) = Number of drugs
    - AY (col 50) = Adult x (proportion * efficacy pre-multiplied)
    - AZ (col 51) = Child x (proportion * efficacy pre-multiplied)
    """
    
    if output_col is None:
        output_col = f"Computed Impact Score ({drug_name})"
    
    # Column indices for country data
    idx_adult_daly = 6   # G - Adult DALYs
    idx_child_daly = 7   # H - Children DALYs
    idx_retention = 8    # I - Retention Rate
    idx_adult_cov = 13   # Q - Adult coverage
    idx_child_cov = 19   # T - Child coverage
    
    if debug:
        print("---- DEBUG ----")
        print(f"Drug: {drug_name}")
        print("Using EXACT Excel formula")
        print("---------------")
    
    # Excel rows to check (from the formula)
    regimen_rows = [5,6,7,8,9,12,13,14,15,16,17,18,21,22,23,24,25,26,27,28,29,31,32,33,34,35,36,37]
    
    scores = []
    
    for i in range(len(main_df)):
        row = main_df.iloc[i]
        
        try:
            G = _to_float(row.iloc[idx_adult_daly])
            H = _to_float(row.iloc[idx_child_daly])
            Q = _to_float(row.iloc[idx_adult_cov])
            T = _to_float(row.iloc[idx_child_cov])
            I = _to_float(row.iloc[idx_retention])
        except:
            scores.append(0.0)
            continue
        
        total = 0.0
        hits = 0
        
        for excel_row in regimen_rows:
            idx = excel_row - 1  # Convert to 0-indexed
            if idx >= len(raw_df):
                continue
            
            regimen = raw_df.iloc[idx, 44]  # AS - regimen name
            if _contains_drug(regimen, drug_name):
                num_drugs = _to_float(raw_df.iloc[idx, 49])  # AX - number of drugs
                adult_x = _to_float(raw_df.iloc[idx, 50])    # AY - adult x (pre-multiplied)
                child_x = _to_float(raw_df.iloc[idx, 51])    # AZ - child x (pre-multiplied)
                
                # Adult: G * Q * adult_x / (1 - Q * adult_x) / num_drugs
                if not pd.isna(adult_x) and not pd.isna(num_drugs) and num_drugs > 0 and not pd.isna(Q):
                    denom_adult = 1.0 - Q * adult_x
                    if denom_adult != 0:
                        total += (G * Q * adult_x / denom_adult) / num_drugs
                
                # Child: H * T * child_x / (1 - T * child_x) / num_drugs
                if not pd.isna(child_x) and not pd.isna(num_drugs) and num_drugs > 0 and not pd.isna(T):
                    denom_child = 1.0 - T * child_x
                    if denom_child != 0:
                        total += (H * T * child_x / denom_child) / num_drugs
                
                hits += 1
        
        # Normalize: / (100/(100-I))
        try:
            norm = 100.0 / (100.0 - I)
            result = total / norm if norm != 0 and not pd.isna(norm) else 0.0
        except:
            result = 0.0
        
        if debug and i < debug_show_first_n_rows:
            country = row.iloc[0]
            print(f"[Row {i}] {country}: hits={hits}, result={result:.6f}")
        
        scores.append(result)
    
    main_df[output_col] = scores
    return main_df

# %% [markdown]
# ## Compute Impact Score for First Drug (with debug)

# %%
# Compute for 3TC first with debug output
main_df = compute_impact_score_2015(
    main_df,
    raw_df,
    "3TC",
    output_col="Computed Impact Score (3TC)",
    debug=True
)

main_df[["Country", "WHO Group", "3TC", "Computed Impact Score (3TC)"]].head(10)
# Out:
# ---- DEBUG ----
# Drug: 3TC
# Using EXACT Excel formula
# ---------------
# [Row 0] Afghanistan: hits=23, result=35.742465
# [Row 1] Albania: hits=23, result=0.000000
# [Row 2] Algeria: hits=23, result=189.858290
# 2              Country              Country WHO Group          3TC  \
# 0          Afghanistan              Albania         A    35.667802
# 1              Albania              Algeria         A            0
# 2              Algeria  Antigua and Barbuda         A   186.166832
# 3       American Samoa            Argentina         A            0
# 4              Andorra              Armenia         A     0.176927
# 5               Angola           Azerbaijan         A  1085.331064
# 6             Anguilla              Bahamas         B            0
# 7  Antigua and Barbuda              Bahrain         B     0.826518
# 8            Argentina           Bangladesh         B   3783.17524
# 9              Armenia             Barbados         A     5.906418
#
# 2  Computed Impact Score (3TC)
# 0                    35.742465
# 1                     0.000000
# 2                   189.858290
# 3                     0.054960
# 4                     0.176927
# 5                  1072.832954
# 6                     0.000000
# 7                     0.826518
# 8                  3835.597657
# 9                     6.067450

# %% [markdown]
# ## Compute for All Drugs

# %%
# List of all drugs (excluding 3TC which is already computed)
drugs = ['ABC', 'AZT', 'ddl', 'd4T', 'EFV', 'FTC', 'LPV/r', 'NVP', 'TDF', 'ATV/r']

for drug in drugs:
    main_df = compute_impact_score_2015(
        main_df,
        raw_df,
        drug,
        debug=False
    )

# %%
main_df.columns
# Out:
# Index([                                                                   'Country',
#                                                                        'WHO Region',
#                                                                        'Population',
#                                                               'Geographical Region',
#                                                                         'WHO Group',
#                                                                              'DALY',
#                                                                       'Adult DALYs',
#                                                                    'Children DALYs',
#                                                                    'Retention Rate',
#                                                            'Retention Rate (ADULT)',
#                                                            'Retention Rate (CHILD)',
#                                                             '# Receiving Treatment',
#                                                               '# Needing Treatment',
#                                                              '% Treatment Coverage',
#                                                             '# Receiving Treatment',
#                                                               '# Needing Treatment',
#                                                              '% Treatment Coverage',
#                                                             '# Receiving Treatment',
#                                                               '# Needing Treatment',
#                                                              '% Treatment Coverage',
#                                            'Estimated adults (15+) living with HIV',
#                                         'Estimated children (0-14) living with HIV',
#                                       '# Adult Prevalent Cases Receiving Treatment',
#                                    '# Children Prevalent Cases Receiving Treatment',
#                                                                               '3TC',
#                                                                               'ABC',
#                                                                               'AZT',
#                                                                               'ddl',
#                                                                               'd4T',
#                                                                               'EFV',
#                                                                               'FTC',
#                                                                             'LPV/r',
#                                                                               'NVP',
#                                                                               'TDF',
#                                                                             'ATV/r',
#                                                          'Overall Treatment Impact',
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#                                        'average of 2013 antiretroviral treatment. ',
#                                                                                 nan,
#                                                                                 nan,
#                                 'Treatment Regimen Proportion and Efficacy Section',
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#              'impact =daly*treatment cover*x/(1-treatment cover*x)/number of drugs',
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#                                                                'Originator Company',
#                                                                           'Drug(s)',
#                                                                      'Final Impact',
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#                                                                                 nan,
#                                                                       'Afghanistan',
#                                                                            9224.366,
#                                                                       'Afghanistan',
#                                                                            1528.182,
#                                                                                 nan,
#                                                                       'Afghanistan',
#                                                                                 500,
#                                                                                  26,
#                                                                                0.11,
#                                                                                 nan,
#                                                                                 nan,
#                                                                           'Country',
#                                                                          'All ages',
#                                                                   'Children (0-14)',
#                                                                      'Adults (15+)',
#                                                                              'Year',
#                                                                                 nan,
#                                'http://apps.who.int/gho/data/node.main.626?lang=en',
#        'Estimated antiretroviral therapy coverage among people living with HIV (%)',
#                        'Reported number of people receiving antiretroviral therapy',
#                                                                  'Cleaned coverage',
#                         'Cleaned number of people receiving antiretroviral therapy',
#                                                       'Computed Impact Score (3TC)',
#                                                       'Computed Impact Score (ABC)',
#                                                       'Computed Impact Score (AZT)',
#                                                       'Computed Impact Score (ddl)',
#                                                       'Computed Impact Score (d4T)',
#                                                       'Computed Impact Score (EFV)',
#                                                       'Computed Impact Score (FTC)',
#                                                     'Computed Impact Score (LPV/r)',
#                                                       'Computed Impact Score (NVP)',
#                                                       'Computed Impact Score (TDF)',
#                                                     'Computed Impact Score (ATV/r)'],
#       dtype='object', name=2)

# %% [markdown]
# ## Compute Overall Treatment Impact

# %%
# List of computed drug columns
computed_drug_cols_wanted = [
    'Computed Impact Score (3TC)',
    'Computed Impact Score (ABC)',
    'Computed Impact Score (AZT)',
    'Computed Impact Score (ddl)',
    'Computed Impact Score (d4T)',
    'Computed Impact Score (EFV)',
    'Computed Impact Score (FTC)',
    'Computed Impact Score (LPV/r)',
    'Computed Impact Score (NVP)',
    'Computed Impact Score (TDF)',
    'Computed Impact Score (ATV/r)',
]

# Keep only existing columns
computed_drug_cols = [c for c in computed_drug_cols_wanted if c in main_df.columns]
missing = [c for c in computed_drug_cols_wanted if c not in main_df.columns]

if missing:
    print("⚠️ Missing computed columns:")
    for m in missing:
        print(f"   - {m}")

# Ensure numeric
for c in computed_drug_cols:
    main_df[c] = pd.to_numeric(main_df[c], errors="coerce")

# Compute overall impact
main_df["Computed Overall Treatment Impact"] = main_df[computed_drug_cols].sum(axis=1, skipna=True)

# %% [markdown]
# ## Global Comparison

# %%
# Global totals comparison
global_computed_total = main_df["Computed Overall Treatment Impact"].sum(skipna=True)
global_actual_total = pd.to_numeric(main_df["Overall Treatment Impact"], errors="coerce").sum(skipna=True)

print("Global totals (sum across countries):")
print(f"  Computed: {global_computed_total}")
print(f"  Actual  : {global_actual_total}")
print(f"  Diff    : {global_computed_total - global_actual_total}")
# Out:
# Global totals (sum across countries):
#   Computed: 2647615.833043346
#   Actual  : 2639736.7135998914
#   Diff    : 7879.11944345478

# %% [markdown]
# ## Detailed Comparison Table

# %%
# Build comparison table like HIV2013
pairs = [
    ("3TC",   "3TC",   "Computed Impact Score (3TC)"),
    ("ABC",   "ABC",   "Computed Impact Score (ABC)"),
    ("AZT",   "AZT",   "Computed Impact Score (AZT)"),
    ("ddl",   "ddl",   "Computed Impact Score (ddl)"),
    ("d4T",   "d4T",   "Computed Impact Score (d4T)"),
    ("EFV",   "EFV",   "Computed Impact Score (EFV)"),
    ("FTC",   "FTC",   "Computed Impact Score (FTC)"),
    ("LPV/r", "LPV/r", "Computed Impact Score (LPV/r)"),
    ("NVP",   "NVP",   "Computed Impact Score (NVP)"),
    ("TDF",   "TDF",   "Computed Impact Score (TDF)"),
    ("ATV/r", "ATV/r", "Computed Impact Score (ATV/r)"),
    ("Overall", "Overall Treatment Impact", "Computed Overall Treatment Impact"),
]

# Keep only pairs where both columns exist
pairs_existing = []
for drug, a, c in pairs:
    if a in main_df.columns and c in main_df.columns:
        pairs_existing.append((drug, a, c))
    else:
        print(f"⚠️ Skipping {drug}: missing column(s)")

# Ensure numeric
for _, a, c in pairs_existing:
    main_df[a] = pd.to_numeric(main_df[a], errors="coerce")
    main_df[c] = pd.to_numeric(main_df[c], errors="coerce")

# Build comparison table
out = main_df[["Country", "WHO Group"]].copy()

for drug, a, c in pairs_existing:
    out[f"{drug} | Actual"] = main_df[a]
    out[f"{drug} | Computed"] = main_df[c]
    out[f"{drug} | Diff (Comp-Act)"] = main_df[c] - main_df[a]

display(out.head(50))
# Out:
# 2                             Country                           Country  \
# 0                         Afghanistan                           Albania
# 1                             Albania                           Algeria
# 2                             Algeria               Antigua and Barbuda
# 3                      American Samoa                         Argentina
# 4                             Andorra                           Armenia
# 5                              Angola                        Azerbaijan
# 6                            Anguilla                           Bahamas
# 7                 Antigua and Barbuda                           Bahrain
# 8                           Argentina                        Bangladesh
# 9                             Armenia                          Barbados
# 10                              Aruba                           Belarus
# 11                          Australia                            Bhutan
# 12                            Austria  Bolivia (Plurinational State of)
# 13                         Azerbaijan            Bosnia and Herzegovina
# 14                            Bahamas                            Brazil
# 15                            Bahrain                          Bulgaria
# 16                         Bangladesh                           Burundi
# 17                           Barbados                          Cambodia
# 18                            Belarus                          Cameroon
# 19                            Belgium                        Cape Verde
# 20                             Belize                             Chile
# 21                              Benin                             China
# 22                            Bermuda                          Colombia
# 23                             Bhutan                     Cote d'Ivoire
# 24                            Bolivia                           Croatia
# 25  Bonaire, Saint Eustatius and Saba                              Cuba
# 26             Bosnia and Herzegovina  Democratic Republic of the Congo
# 27                           Botswana                          Djibouti
# 28                             Brazil                          Dominica
# 29             British Virgin Islands                Dominican Republic
# 30                  Brunei Darussalam                             Egypt
# 31                           Bulgaria                       El Salvador
# 32                       Burkina Faso                           Eritrea
# 33                            Burundi                              Fiji
# 34                           Cambodia                           Finland
# 35                           Cameroon                            Gambia
# 36                             Canada                           Georgia
# 37                         Cape Verde                            Greece
# 38                     Cayman Islands                           Grenada
# 39           Central African Republic                         Guatemala
# 40                               Chad                            Guyana
# 41                              Chile                          Honduras
# 42                              China        Iran (Islamic Republic of)
# 43               China, Hong Kong SAR                           Jamaica
# 44                   China, Macao SAR                            Jordan
# 45                           Colombia                        Kazakhstan
# 46                            Comoros                             Kenya
# 47                              Congo                          Kiribati
# 48                       Cook Islands                        Kyrgyzstan
# 49                         Costa Rica  Lao People's Democratic Republic
#
# 2  WHO Group  3TC | Actual  3TC | Computed  3TC | Diff (Comp-Act)  \
# 0          A     35.667802       35.742465           7.466270e-02
# 1          A      0.000000        0.000000           0.000000e+00
# 2          A    186.166832      189.858290           3.691457e+00
# 3          A      0.000000        0.054960           5.496046e-02
# 4          A      0.176927        0.176927          -9.965223e-12
# 5          A   1085.331064     1072.832954          -1.249811e+01
# 6          B      0.000000        0.000000           0.000000e+00
# 7          B      0.826518        0.826518           5.368250e-11
# 8          B   3783.175240     3835.597657           5.242242e+01
# 9          A      5.906418        6.067450           1.610319e-01
# 10         B      0.000000        0.000000           0.000000e+00
# 11         A     28.294966       28.201481          -9.348470e-02
# 12         A      0.000000        0.000000           0.000000e+00
# 13         A     25.934414       26.329352           3.949379e-01
# 14         B      0.000000        0.000000           0.000000e+00
# 15         A     38.031942       38.031942           3.726598e-09
# 16         A     96.365472       97.232623           8.671507e-01
# 17         B     17.258691       17.389548           1.308563e-01
# 18         A    131.777716      133.982331           2.204615e+00
# 19         A      0.000000        0.000000           0.000000e+00
# 20         B     14.648976       14.631713          -1.726286e-02
# 21         A    400.556193      395.281165          -5.275028e+00
# 22         B      0.877360        0.877360           2.140066e-12
# 23         A      1.018766        1.018766          -3.303133e-10
# 24         B     28.959034        9.398926          -1.956011e+01
# 25         B      0.000000        0.000000           0.000000e+00
# 26         A      0.000000        0.000000           0.000000e+00
# 27         A   2332.291709     2348.382977           1.609127e+01
# 28         B  26289.592340    26379.358560           8.976622e+01
# 29         B      0.000000        0.000000           0.000000e+00
# 30         A      0.000000        0.000000           0.000000e+00
# 31         A      0.000000        0.000000           0.000000e+00
# 32         A    577.008500      557.751407          -1.925709e+01
# 33         A   2295.019424     2176.492795          -1.185266e+02
# 34         A   3983.284772     3983.284772           4.307349e-07
# 35         A  38770.317380    38011.556971          -7.587604e+02
# 36         B     34.199834       34.199834          -2.107804e-09
# 37         A     14.046868       14.269698           2.228300e-01
# 38         B      0.000000        0.000000           0.000000e+00
# 39         A    620.377009      623.436822           3.059813e+00
# 40         A   1037.427118      994.962329          -4.246479e+01
# 41         B    123.016006      123.753807           7.378005e-01
# 42         A  11785.550320    11785.550315          -4.835356e-06
# 43         A      0.000000        0.000000           0.000000e+00
# 44         A      0.000000        0.000000           0.000000e+00
# 45         B   8179.975227     8179.975227          -4.841513e-08
# 46         A      1.836154        1.836154          -5.207901e-11
# 47         A    426.333301      426.333301          -7.882011e-08
# 48         A      0.000000        0.000000           0.000000e+00
# 49         B     25.390575       25.170969          -2.196064e-01
#
# 2   ABC | Actual  ABC | Computed  ABC | Diff (Comp-Act)  AZT | Actual  ...  \
# 0       3.483114        3.483425           3.106033e-04     15.831563  ...
# 1       0.000000        0.000000           0.000000e+00      0.000000  ...
# 2       3.714239        3.725742           1.150353e-02     70.801802  ...
# 3       0.000000        0.000219           2.192879e-04      0.000000  ...
# 4       0.000706        0.000706           5.924818e-14      0.065802  ...
# 5      84.823245       84.775053          -4.819174e-02    466.427030  ...
# 6       0.000000        0.000000           0.000000e+00      0.000000  ...
# 7       0.003298        0.003298          -2.455805e-14      0.307398  ...
# 8     122.256802      122.436603           1.798018e-01   1502.665107  ...
# 9       0.023988        0.024616           6.280641e-04      2.206146  ...
# 10      0.000000        0.000000           0.000000e+00      0.000000  ...
# 11      0.419613        0.419322          -2.902691e-04     10.592122  ...
# 12      0.000000        0.000000           0.000000e+00      0.000000  ...
# 13      0.409443        0.410973           1.529872e-03      9.971884  ...
# 14      0.000000        0.000000           0.000000e+00      0.000000  ...
# 15      0.151744        0.151744           7.261969e-13     14.144805  ...
# 16      5.811428        5.814927           3.499002e-03     40.352801  ...
# 17      0.068148        0.068631           4.823376e-04      6.402401  ...
# 18      1.052728        1.061488           8.759598e-03     49.841856  ...
# 19      0.000000        0.000000           0.000000e+00      0.000000  ...
# 20      0.694094        0.694031          -6.294939e-05      6.037697  ...
# 21     30.520220       30.501205          -1.901524e-02    171.854463  ...
# 22      0.003501        0.003501           4.931650e-13      0.326307  ...
# 23      0.004139        0.004139          -8.671813e-13      0.380549  ...
# 24      0.103199        0.037501          -6.569834e-02     10.451576  ...
# 25      0.000000        0.000000           0.000000e+00      0.000000  ...
# 26      0.000000        0.000000           0.000000e+00      0.000000  ...
# 27     99.982768      100.035163           5.239514e-02    947.065281  ...
# 28    698.933516      699.250983           3.174671e-01  10268.913290  ...
# 29      0.000000        0.000000           0.000000e+00      0.000000  ...
# 30      0.000000        0.000000           0.000000e+00      0.000000  ...
# 31      0.000000        0.000000           0.000000e+00      0.000000  ...
# 32     36.289744       36.221919          -6.782555e-02    239.957374  ...
# 33    131.432695      131.014589          -4.181068e-01    943.381682  ...
# 34     14.901243       14.901243          -3.014675e-09   1457.168045  ...
# 35   1603.059810     1600.115887          -2.943923e+00  15553.800700  ...
# 36      0.136455        0.136455          -3.621381e-12     12.719571  ...
# 37      0.056095        0.056935           8.400551e-04      5.225415  ...
# 38      0.000000        0.000000           0.000000e+00      0.000000  ...
# 39     33.746661       33.758661           1.200054e-02    255.791101  ...
# 40     63.297517       63.137847          -1.596705e-01    430.892467  ...
# 41      0.449735        0.452056           2.320956e-03     44.719888  ...
# 42     47.877723       47.877723          -8.036878e-09   4402.361080  ...
# 43      0.000000        0.000000           0.000000e+00      0.000000  ...
# 44      0.000000        0.000000           0.000000e+00      0.000000  ...
# 45     29.150415       29.150415           3.809674e-09   2952.226692  ...
# 46      0.007333        0.007333          -1.185654e-12      0.683047  ...
# 47      1.702524        1.702524          -5.911205e-10    158.595377  ...
# 48      0.000000        0.000000           0.000000e+00      0.000000  ...
# 49      0.607119        0.606346          -7.730473e-04      9.804784  ...
#
# 2   NVP | Diff (Comp-Act)  TDF | Actual  TDF | Computed  \
# 0            3.071683e-02     23.749159       23.113528
# 1            0.000000e+00      0.000000        0.000000
# 2            1.428887e+00    164.992819      164.127475
# 3            2.244353e-02      0.000000        0.049874
# 4            3.094067e-12      0.165287        0.160553
# 5           -5.072977e+00    780.409167      746.712865
# 6            0.000000e+00      0.000000        0.000000
# 7            3.936457e-11      0.772143        0.750028
# 8            2.076645e+01   3192.017671     3153.376046
# 9            6.550314e-02      5.511532        5.497166
# 10           0.000000e+00      0.000000        0.000000
# 11          -3.615241e-02     25.567095       24.817645
# 12           0.000000e+00      0.000000        0.000000
# 13           1.604444e-01     23.237268       22.922279
# 14           0.000000e+00      0.000000        0.000000
# 15           2.819171e-09     35.529906       34.512260
# 16           3.549029e-01     74.030992       72.640237
# 17           5.264596e-02     16.134117       15.796590
# 18           8.998247e-01    121.229983      119.663245
# 19           0.000000e+00      0.000000        0.000000
# 20          -6.929826e-03     11.682345       11.339676
# 21          -2.112465e+00    289.014673      276.196798
# 22          -1.676026e-11      0.819640        0.796164
# 23          -5.200329e-11      0.950639        0.922897
# 24          -7.702821e+00     27.252306        8.529099
# 25           0.000000e+00      0.000000        0.000000
# 26           0.000000e+00      0.000000        0.000000
# 27           6.297149e+00   1889.837275     1854.716119
# 28           3.580188e+01  22729.252850    22183.174388
# 29           0.000000e+00      0.000000        0.000000
# 30           0.000000e+00      0.000000        0.000000
# 31           0.000000e+00      0.000000        0.000000
# 32          -7.673537e+00    440.485226      410.762013
# 33          -4.724608e+01   1790.824206     1633.023224
# 34           4.227709e-07   3736.778155     3636.693772
# 35          -3.083408e+02  32035.348140    30419.208695
# 36          -2.389989e-09     31.949904       31.034796
# 37           9.005360e-02     13.122015       12.949103
# 38           0.000000e+00      0.000000        0.000000
# 39           1.245925e+00    488.388638      477.001998
# 40          -1.715268e+01    798.433768      737.088530
# 41           2.862741e-01    115.574944      113.236533
# 42          -6.898254e-07  10997.427250    10676.489183
# 43           0.000000e+00      0.000000        0.000000
# 44           0.000000e+00      0.000000        0.000000
# 45           4.585763e-07   7697.880651     7501.885352
# 46          -9.489398e-11      1.715261        1.666088
# 47          -3.662797e-08    398.263309      386.845897
# 48           0.000000e+00      0.000000        0.000000
# 49          -8.749793e-02     22.230952       21.416307
#
# 2   TDF | Diff (Comp-Act)  ATV/r | Actual  ATV/r | Computed  \
# 0               -0.635631        0.412628          0.413849
# 1                0.000000        0.000000          0.000000
# 2               -0.865344        2.513475          2.558872
# 3                0.049874        0.000000          0.000863
# 4               -0.004734        0.002777          0.002777
# 5              -33.696302       13.092495         12.902838
# 6                0.000000        0.000000          0.000000
# 7               -0.022116        0.012972          0.012972
# 8              -38.641625       50.927850         51.636571
# 9               -0.014366        0.094334          0.096806
# 10               0.000000        0.000000          0.000000
# 11              -0.749450        0.388341          0.387196
# 12               0.000000        0.000000          0.000000
# 13              -0.314989        0.395596          0.401616
# 14               0.000000        0.000000          0.000000
# 15              -1.017646        0.596887          0.596887
# 16              -1.390755        1.277251          1.291012
# 17              -0.337526        0.268101          0.270000
# 18              -1.566737        2.093401          2.127859
# 19               0.000000        0.000000          0.000000
# 20              -0.342669        0.191691          0.191443
# 21             -12.817875        4.683175          4.608272
# 22              -0.023476        0.013770          0.013770
# 23              -0.027743        0.016275          0.016275
# 24             -18.723207        0.406527          0.147510
# 25               0.000000        0.000000          0.000000
# 26               0.000000        0.000000          0.000000
# 27             -35.121156       29.300533         29.507192
# 28            -546.078462      368.483405        369.734261
# 29               0.000000        0.000000          0.000000
# 30               0.000000        0.000000          0.000000
# 31               0.000000        0.000000          0.000000
# 32             -29.723213        7.064369          6.797115
# 33            -157.800982       28.746899         27.099456
# 34            -100.084383       58.664572         58.664572
# 35           -1616.139445      543.110606        531.525868
# 36              -0.915107        0.536744          0.536744
# 37              -0.172913        0.220647          0.223954
# 38               0.000000        0.000000          0.000000
# 39             -11.386641        8.311676          8.358893
# 40             -61.345238       13.254716         12.626115
# 41              -2.338411        1.771069          1.780228
# 42            -320.938067      188.278886        188.278886
# 43               0.000000        0.000000          0.000000
# 44               0.000000        0.000000          0.000000
# 45            -195.995299      114.830534        114.830534
# 46              -0.049173        0.028842          0.028842
# 47             -11.417411        6.696798          6.696798
# 48               0.000000        0.000000          0.000000
# 49              -0.814645        0.359465          0.356419
#
# 2   ATV/r | Diff (Comp-Act)  Overall | Actual  Overall | Computed  \
# 0              1.221020e-03        129.229982          128.814112
# 1              0.000000e+00          0.000000            0.000000
# 2              4.539665e-02        710.727413          720.593201
# 3              8.625692e-04          0.000000            0.211411
# 4             -9.394785e-14          0.685301            0.680567
# 5             -1.896577e-01       3984.248983         3913.861891
# 6              0.000000e+00          0.000000            0.000000
# 7              4.902245e-12          3.201400            3.179284
# 8              7.087207e-01      14313.300080        14427.796753
# 9              2.471334e-03         22.882402           23.340979
# 10             0.000000e+00          0.000000            0.000000
# 11            -1.145544e-03        108.464753          107.443596
# 12             0.000000e+00          0.000000            0.000000
# 13             6.020392e-03         99.554255          100.398887
# 14             0.000000e+00          0.000000            0.000000
# 15            -1.694767e-11        147.311266          146.293620
# 16             1.376127e-02        358.417796          359.576862
# 17             1.899415e-03         66.840073           66.886023
# 18             3.445847e-02        508.998071          513.910474
# 19             0.000000e+00          0.000000            0.000000
# 20            -2.479268e-04         54.829046           54.435811
# 21            -7.490328e-02       1470.302991         1442.041027
# 22             1.203738e-12          3.398326            3.374850
# 23            -7.631517e-12          3.946872            3.919130
# 24            -2.590169e-01        111.943185           36.153897
# 25             0.000000e+00          0.000000            0.000000
# 26             0.000000e+00          0.000000            0.000000
# 27             2.066590e-01       8744.407475         8756.172910
# 28             1.250856e+00     100018.503100        99735.020687
# 29             0.000000e+00          0.000000            0.000000
# 30             0.000000e+00          0.000000            0.000000
# 31             0.000000e+00          0.000000            0.000000
# 32            -2.672547e-01       2140.058307         2054.012029
# 33            -1.647443e+00       8548.404939         8043.914012
# 34             2.043585e-09      15413.331910        15313.247530
# 35            -1.158474e+01     146268.091800       142423.940310
# 36             3.142742e-11        132.468145          131.553037
# 37             3.307063e-03         54.409116           54.889801
# 38             0.000000e+00          0.000000            0.000000
# 39             4.721649e-02       2317.879584         2315.481268
# 40            -6.286011e-01       3856.830172         3670.941423
# 41             9.158217e-03        475.795714          475.603204
# 42            -7.063758e-08      45659.219020        45338.280942
# 43             0.000000e+00          0.000000            0.000000
# 44             0.000000e+00          0.000000            0.000000
# 45             4.958034e-08      31620.270130        31424.274829
# 46            -3.081944e-12          7.112158            7.062985
# 47            -6.727259e-10       1651.358743         1639.941331
# 48             0.000000e+00          0.000000            0.000000
# 49            -3.046080e-03         96.851998           95.395064
#
# 2   Overall | Diff (Comp-Act)
# 0                   -0.415870
# 1                    0.000000
# 2                    9.865788
# 3                    0.211411
# 4                   -0.004734
# 5                  -70.387092
# 6                    0.000000
# 7                   -0.022116
# 8                  114.496673
# 9                    0.458576
# 10                   0.000000
# 11                  -1.021158
# 12                   0.000000
# 13                   0.844632
# 14                   0.000000
# 15                  -1.017646
# 16                   1.159066
# 17                   0.045950
# 18                   4.912403
# 19                   0.000000
# 20                  -0.393235
# 21                 -28.261964
# 22                  -0.023476
# 23                  -0.027743
# 24                 -75.789287
# 25                   0.000000
# 26                   0.000000
# 27                  11.765435
# 28                -283.482413
# 29                   0.000000
# 30                   0.000000
# 31                   0.000000
# 32                 -86.046278
# 33                -504.490927
# 34                -100.084380
# 35               -3844.151490
# 36                  -0.915108
# 37                   0.480685
# 38                   0.000000
# 39                  -2.398316
# 40                -185.888749
# 41                  -0.192511
# 42                -320.938078
# 43                   0.000000
# 44                   0.000000
# 45                -195.995301
# 46                  -0.049173
# 47                 -11.417412
# 48                   0.000000
# 49                  -1.456934
#
# [50 rows x 39 columns]

# %% [markdown]
# ## Show All Data

# %%
pd.set_option('display.max_rows', None)
main_df
# Out:
# 2                                              Country  \
# 0                                          Afghanistan
# 1                                              Albania
# 2                                              Algeria
# 3                                       American Samoa
# 4                                              Andorra
# 5                                               Angola
# 6                                             Anguilla
# 7                                  Antigua and Barbuda
# 8                                            Argentina
# 9                                              Armenia
# 10                                               Aruba
# 11                                           Australia
# 12                                             Austria
# 13                                          Azerbaijan
# 14                                             Bahamas
# 15                                             Bahrain
# 16                                          Bangladesh
# 17                                            Barbados
# 18                                             Belarus
# 19                                             Belgium
# 20                                              Belize
# 21                                               Benin
# 22                                             Bermuda
# 23                                              Bhutan
# 24                                             Bolivia
# 25                   Bonaire, Saint Eustatius and Saba
# 26                              Bosnia and Herzegovina
# 27                                            Botswana
# 28                                              Brazil
# 29                              British Virgin Islands
# 30                                   Brunei Darussalam
# 31                                            Bulgaria
# 32                                        Burkina Faso
# 33                                             Burundi
# 34                                            Cambodia
# 35                                            Cameroon
# 36                                              Canada
# 37                                          Cape Verde
# 38                                      Cayman Islands
# 39                            Central African Republic
# 40                                                Chad
# 41                                               Chile
# 42                                               China
# 43                                China, Hong Kong SAR
# 44                                    China, Macao SAR
# 45                                            Colombia
# 46                                             Comoros
# 47                                               Congo
# 48                                        Cook Islands
# 49                                          Costa Rica
# 50                                       Cote d'Ivoire
# 51                                             Croatia
# 52                                                Cuba
# 53                                             Curacao
# 54                                              Cyprus
# 55                                      Czech Republic
# 56               Democratic People's Republic of Korea
# 57                    Democratic Republic of the Congo
# 58                                             Denmark
# 59                                            Djibouti
# 60                                            Dominica
# 61                                  Dominican Republic
# 62                                             Ecuador
# 63                                               Egypt
# 64                                         El Salvador
# 65                                   Equatorial Guinea
# 66                                             Eritrea
# 67                                             Estonia
# 68                                            Ethiopia
# 69                                                Fiji
# 70                                             Finland
# 71                                              France
# 72                                    French Polynesia
# 73                                               Gabon
# 74                                              Gambia
# 75                                             Georgia
# 76                                             Germany
# 77                                               Ghana
# 78                                              Greece
# 79                                           Greenland
# 80                                             Grenada
# 81                                                Guam
# 82                                           Guatemala
# 83                                              Guinea
# 84                                       Guinea-Bissau
# 85                                              Guyana
# 86                                               Haiti
# 87                                            Honduras
# 88                                             Hungary
# 89                                             Iceland
# 90                                               India
# 91                                           Indonesia
# 92                                                Iran
# 93                                                Iraq
# 94                                             Ireland
# 95                                              Israel
# 96                                               Italy
# 97                                             Jamaica
# 98                                               Japan
# 99                                              Jordan
# 100                                         Kazakhstan
# 101                                              Kenya
# 102                                           Kiribati
# 103                                             Kuwait
# 104                                         Kyrgyzstan
# 105                   Lao People's Democratic Republic
# 106                                             Latvia
# 107                                            Lebanon
# 108                                            Lesotho
# 109                                            Liberia
# 110                                              Libya
# 111                                          Lithuania
# 112                                         Luxembourg
# 113                                         Madagascar
# 114                                             Malawi
# 115                                           Malaysia
# 116                                           Maldives
# 117                                               Mali
# 118                                              Malta
# 119                                   Marshall Islands
# 120                                         Mauritania
# 121                                          Mauritius
# 122                                             Mexico
# 123                   Micronesia (Federated States of)
# 124                                             Monaco
# 125                                           Mongolia
# 126                                         Montenegro
# 127                                         Montserrat
# 128                                            Morocco
# 129                                         Mozambique
# 130                                            Myanmar
# 131                                            Namibia
# 132                                              Nauru
# 133                                              Nepal
# 134                                        Netherlands
# 135                                      New Caledonia
# 136                                        New Zealand
# 137                                          Nicaragua
# 138                                              Niger
# 139                                            Nigeria
# 140                                               Niue
# 141                           Northern Mariana Islands
# 142                                             Norway
# 143                                               Oman
# 144                                           Pakistan
# 145                                              Palau
# 146                                             Panama
# 147                                   Papua New Guinea
# 148                                           Paraguay
# 149                                               Peru
# 150                                        Philippines
# 151                                             Poland
# 152                                           Portugal
# 153                                        Puerto Rico
# 154                                              Qatar
# 155                                  Republic of Korea
# 156                                Republic of Moldova
# 157                                            Romania
# 158                                             Russia
# 159                                             Rwanda
# 160                              Saint Kitts and Nevis
# 161                                        Saint Lucia
# 162                   Saint Vincent and the Grenadines
# 163                                              Samoa
# 164                                         San Marino
# 165                              Sao Tome and Principe
# 166                                       Saudi Arabia
# 167                                            Senegal
# 168                                             Serbia
# 169                                         Seychelles
# 170                                       Sierra Leone
# 171                                          Singapore
# 172                          Sint Maarten (Dutch part)
# 173                                           Slovakia
# 174                                           Slovenia
# 175                                    Solomon Islands
# 176                                            Somalia
# 177                                       South Africa
# 178                                        South Sudan
# 179                                              Spain
# 180                                          Sri Lanka
# 181                                              Sudan
# 182                                           Suriname
# 183                                          Swaziland
# 184                                             Sweden
# 185                                        Switzerland
# 186                               Syrian Arab Republic
# 187                                         Tajikistan
# 188                                           Tanzania
# 189                                           Thailand
# 190          The Former Yugoslav Republic of Macedonia
# 191                                        Timor-Leste
# 192                                               Togo
# 193                                            Tokelau
# 194                                              Tonga
# 195                                Trinidad and Tobago
# 196                                            Tunisia
# 197                                             Turkey
# 198                                       Turkmenistan
# 199                           Turks and Caicos Islands
# 200                                             Tuvalu
# 201                                             Uganda
# 202                                            Ukraine
# 203                               United Arab Emirates
# 204  United Kingdom of Great Britain and Northern I...
# 205                                      United States
# 206                                            Uruguay
# 207                                  US Virgin Islands
# 208                                         Uzbekistan
# 209                                            Vanuatu
# 210                                          Venezuela
# 211                                           Viet Nam
# 212                          Wallis and Futuna Islands
# 213                           West Bank and Gaza Strip
# 214                                              Yemen
# 215                                             Zambia
# 216                                           Zimbabwe
# 217                                                NaN
# 218                             Sources / More details
# 219                             WHO groupings (A & B):
# 220                           Antiretroviral coverage:
# 221                                 Regimen breakdowns
# 222                            Drugs and manufacturers
# 223                                                NaN
# 224                                                NaN
# 225                                                NaN
# 226                                                NaN
# 227                                                NaN
# 228                                                NaN
# 229                                                NaN
# 230                                                NaN
# 231                                                NaN
# 232                                                NaN
# 233                                                NaN
#
# 2                                           WHO Region   Population  \
# 0                                                  EMR     33736494
# 1                                                  EUR      2880703
# 2                                                  AFR     39871528
# 3                                                  WPR        55537
# 4                                                  EUR        78014
# 5                                                  AFR     27859305
# 6                                                  AMR        14723
# 7                                                  AMR        99923
# 8                                                  AMR     43417765
# 9                                                  EUR      2916950
# 10                                                 AMR       104341
# 11                                                 WPR     23789338
# 12                                                 EUR      8633169
# 13                                                 EUR      9649341
# 14                                                 AMR       386838
# 15                                                 EMR      1371855
# 16                                                 SEA    161200886
# 17                                                 AMR       284217
# 18                                                 EUR      9489616
# 19                                                 EUR     11274196
# 20                                                 AMR       359288
# 21                                                 AFR     10575952
# 22                                                 AMR        65235
# 23                                                 SEA       787386
# 24                                                 AMR     10724705
# 25                                                 AMR          NaN
# 26                                                 EUR      3535961
# 27                                                 AFR      2209197
# 28                                                 AMR    205962108
# 29                                                 AMR        30113
# 30                                                 WPR       417542
# 31                                                 EUR      7177991
# 32                                                 AFR     18110624
# 33                                                 AFR     10199270
# 34                                                 WPR     15517635
# 35                                                 AFR     22834522
# 36                                                 AMR     35848610
# 37                                                 AFR       532913
# 38                                                 AMR        59963
# 39                                                 AFR      4546100
# 40                                                 AFR     14009413
# 41                                                 AMR     17762681
# 42                                                 WPR   1371220000
# 43                                                 WPR      7305700
# 44                                                 WPR       600942
# 45                                                 AMR     48228697
# 46                                                 AFR       777424
# 47                                                 AFR      4995648
# 48                                                 WPR        18800
# 49                                                 AMR      4807852
# 50                                                 AFR     23108472
# 51                                                 EUR      4203604
# 52                                                 AMR     11461432
# 53                                                 AMR       157979
# 54                                                 EUR      1160985
# 55                                                 EUR     10546059
# 56                                                 SEA     25243917
# 57                                                 AFR     76196619
# 58                                                 EUR      5683483
# 59                                                 EMR       927414
# 60                                                 AMR        73162
# 61                                                 AMR     10528394
# 62                                                 AMR     16144368
# 63                                                 EMR     93778172
# 64                                                 AMR      6312478
# 65                                                 AFR      1175389
# 66                                                 AFR          NaN
# 67                                                 EUR      1315407
# 68                                                 AFR     99873033
# 69                                                 WPR       892149
# 70                                                 EUR      5479531
# 71                                                 EUR     66624068
# 72                                                 WPR       277690
# 73                                                 AFR      1930175
# 74                                                 AFR      1977590
# 75                                                 EUR      3717100
# 76                                                 EUR     81686611
# 77                                                 AFR     27582821
# 78                                                 EUR     10820883
# 79                                                 EUR        56114
# 80                                                 AMR       106823
# 81                                                 WPR       161797
# 82                                                 AMR     16252429
# 83                                                 AFR     12091533
# 84                                                 AFR      1770526
# 85                                                 AMR       768514
# 86                                                 AMR     10711061
# 87                                                 AMR      8960829
# 88                                                 EUR      9843028
# 89                                                 EUR       330815
# 90                                                 SEA   1309053980
# 91                                                 SEA    258162113
# 92                                                 EMR     79360487
# 93                                                 EMR     36115649
# 94                                                 EUR      4676835
# 95                                                 EUR      8380100
# 96                                                 EUR     60730582
# 97                                                 AMR      2871934
# 98                                                 WPR    127141000
# 99                                                 EMR      9159302
# 100                                                EUR     17544126
# 101                                                AFR     47236259
# 102                                                WPR       112407
# 103                                                EMR      3935794
# 104                                                EUR      5956900
# 105                                                WPR      6663967
# 106                                                EUR      1977527
# 107                                                EMR      5851479
# 108                                                AFR      2174645
# 109                                                AFR      4499621
# 110                                                EMR      6234955
# 111                                                EUR      2904910
# 112                                                EUR       569604
# 113                                                AFR     24234088
# 114                                                AFR     17573607
# 115                                                WPR     30723155
# 116                                                SEA       409163
# 117                                                AFR     17467905
# 118                                                EUR       431874
# 119                                                WPR        52994
# 120                                                AFR      4182341
# 121                                                AFR      1262605
# 122                                                AMR    125890949
# 123                                                WPR       104433
# 124                                                EUR        38307
# 125                                                WPR      2976877
# 126                                                EUR       622159
# 127                                                AMR         5012
# 128                                                EMR     34803322
# 129                                                AFR     28010691
# 130                                                SEA     52403669
# 131                                                AFR      2425561
# 132                                                WPR        12475
# 133                                                SEA     28656282
# 134                                                EUR     16939923
# 135                                                WPR       273000
# 136                                                WPR      4595700
# 137                                                AMR      6082035
# 138                                                AFR     19896965
# 139                                                AFR    181181744
# 140                                                WPR          NaN
# 141                                                WPR        54816
# 142                                                EUR      5188607
# 143                                                EMR      4199810
# 144                                                EMR    189380513
# 145                                                WPR        21288
# 146                                                AMR      3969249
# 147                                                WPR      7919825
# 148                                                AMR      6639119
# 149                                                AMR     31376671
# 150                                                WPR    101716359
# 151                                                EUR     37986412
# 152                                                EUR     10358076
# 153                                                AMR      3473181
# 154                                                EMR      2481539
# 155                                                WPR     51014947
# 156                                                EUR      3554108
# 157                                                EUR     19815481
# 158                                                EUR    144096870
# 159                                                AFR     11629553
# 160                                                AMR        54288
# 161                                                AMR       177206
# 162                                                AMR       109455
# 163                                                WPR       193759
# 164                                                EUR        32960
# 165                                                AFR       195553
# 166                                                EMR     31557144
# 167                                                AFR     14976994
# 168                                                EUR      7095383
# 169                                                AFR        93419
# 170                                                AFR      7237025
# 171                                                WPR      5535002
# 172                                                AMR        38824
# 173                                                EUR      5423801
# 174                                                EUR      2063531
# 175                                                WPR       587482
# 176                                                EMR     13908129
# 177                                                AFR  55011976.68
# 178                                                AFR     11882136
# 179                                                EUR     46447697
# 180                                                SEA     20966000
# 181                                                EMR     38647803
# 182                                                AMR       553208
# 183                                                AFR      1319011
# 184                                                EUR      9799186
# 185                                                EUR      8282396
# 186                                                EMR     18734987
# 187                                                EUR      8548651
# 188                                                AFR     53879957
# 189                                                SEA     68657600
# 190                                                EUR      2079308
# 191                                                SEA      1240977
# 192                                                AFR      7416802
# 193                                                WPR          NaN
# 194                                                WPR       106364
# 195                                                AMR      1360092
# 196                                                EMR     11273661
# 197                                                EUR     78271472
# 198                                                EUR      5565284
# 199                                                AMR        34339
# 200                                                WPR        11001
# 201                                                AFR     40144870
# 202                                                EUR     45154029
# 203                                                EMR      9154302
# 204                                                EUR     65128861
# 205                                                AMR    320896618
# 206                                                AMR      3431552
# 207                                                AMR       103574
# 208                                                EUR     31298900
# 209                                                WPR       264603
# 210                                                AMR     31155134
# 211                                                WPR     91713300
# 212                                                WPR          NaN
# 213                                                EMR      4422143
# 214                                                EMR     26916207
# 215                                                AFR     16100587
# 216                                                AFR     15777451
# 217                                                NaN          NaN
# 218                                                NaN          NaN
# 219  https://docs.google.com/spreadsheet/ccc?key=0A...          NaN
# 220  https://docs.google.com/spreadsheet/ccc?key=0A...          NaN
# 221  https://docs.google.com/spreadsheet/ccc?key=0A...          NaN
# 222  https://docs.google.com/spreadsheet/ccc?key=0A...          NaN
# 223                                                NaN          NaN
# 224                                                NaN          NaN
# 225                                                NaN          NaN
# 226                                                NaN          NaN
# 227                                                NaN          NaN
# 228                                                NaN          NaN
# 229                                                NaN          NaN
# 230                                                NaN          NaN
# 231                                                NaN          NaN
# 232                                                NaN          NaN
# 233                                                NaN          NaN
#
# 2                Geographical Region WHO Group         DALY Adult DALYs  \
# 0    East, South and South-East Asia         A    10752.548    9224.366
# 1            Europe and Central Asia         A    98.495261    96.59686
# 2       Middle East and North Africa         A   11586.0447    11055.12
# 3                                NaN         A    28.518669    25.84525
# 4                                NaN         A     83.36974    83.20017
# 5                 Sub-Saharan Africa         A     648951.4    485015.9
# 6                                NaN         B            0           0
# 7                                NaN         B    413.85098    388.6716
# 8    Latin America and the Caribbean         B    78326.475    73886.85
# 9            Europe and Central Asia         A   776.945553    773.9614
# 10                               NaN         B            0           0
# 11                               NaN         A    4843.3814    4679.178
# 12           Europe and Central Asia         A     2459.371    2459.371
# 13           Europe and Central Asia         A   5023.63795    4968.917
# 14                               NaN         B            0           0
# 15                               NaN         A   1010.22416    983.6522
# 16   East, South and South-East Asia         A    14639.534    13423.63
# 17                               NaN         B   1147.37048    1087.004
# 18           Europe and Central Asia         A  25579.95697    25524.06
# 19           Europe and Central Asia         A    2967.7482    2829.539
# 20   Latin America and the Caribbean         B    4908.0796    4533.936
# 21                Sub-Saharan Africa         A    138371.07    102444.2
# 22                               NaN         B    423.29115    412.5798
# 23   East, South and South-East Asia         A     925.7444    704.6815
# 24   Latin America and the Caribbean         B   4443.13998    4419.861
# 25                               NaN         B            0           0
# 26           Europe and Central Asia         A   140.671979    137.4223
# 27                Sub-Saharan Africa         A    456310.92      411632
# 28   Latin America and the Caribbean         B    956427.18    910360.7
# 29                               NaN         B            0           0
# 30                               NaN         A            0           0
# 31           Europe and Central Asia         A    2598.9491    2487.548
# 32                Sub-Saharan Africa         A    188047.49    134589.2
# 33                Sub-Saharan Africa         A     215208.1    156313.8
# 34   East, South and South-East Asia         A   126973.454    117498.3
# 35                Sub-Saharan Africa         A    1816622.7     1534503
# 36                               NaN         B   16383.1556    16082.53
# 37                Sub-Saharan Africa         A    5084.1016      4797.9
# 38                               NaN         B            0           0
# 39                Sub-Saharan Africa         A    440786.14    379740.6
# 40                Sub-Saharan Africa         A     513923.7    382228.3
# 41   Latin America and the Caribbean         B   21904.0186     21219.3
# 42   East, South and South-East Asia         A    1911023.9     1793457
# 43                               NaN         A            0           0
# 44                               NaN         A            0           0
# 45   Latin America and the Caribbean         B   117655.143    111581.6
# 46                Sub-Saharan Africa         A    1012.4449     877.152
# 47                Sub-Saharan Africa         A    272654.24    203664.3
# 48                           Oceania         A            0           0
# 49   Latin America and the Caribbean         B    7391.4216    6931.142
# 50                Sub-Saharan Africa         A    1245070.1    978347.4
# 51           Europe and Central Asia         A    297.39673    276.0722
# 52   Latin America and the Caribbean         B   15983.0452     15270.3
# 53                               NaN         B            0           0
# 54           Europe and Central Asia         A    159.92717      159.06
# 55           Europe and Central Asia         A    704.50299    648.4643
# 56   East, South and South-East Asia         A            0           0
# 57                Sub-Saharan Africa         A    2026782.6     1478999
# 58           Europe and Central Asia         A   1596.08977    1569.254
# 59                               NaN         A    20695.523    17097.56
# 60   Latin America and the Caribbean         B    300.98637    289.4071
# 61   Latin America and the Caribbean         B    96429.671    89754.48
# 62   Latin America and the Caribbean         B   37273.0106    36970.94
# 63      Middle East and North Africa         A    11122.528    9186.052
# 64   Latin America and the Caribbean         B   25209.1291    24380.72
# 65                Sub-Saharan Africa         A     45351.99    35612.91
# 66                Sub-Saharan Africa         A     47710.57    33785.33
# 67           Europe and Central Asia         A   1867.78868    1846.886
# 68                Sub-Saharan Africa         A    1639891.3     1227515
# 69                           Oceania         A    1165.8095    1054.248
# 70           Europe and Central Asia         A    395.10414    377.3627
# 71           Europe and Central Asia         A   26183.8386    25608.36
# 72                               NaN         A            0           0
# 73                Sub-Saharan Africa         A    62694.715    59623.49
# 74                Sub-Saharan Africa         A            0           0
# 75           Europe and Central Asia         A   1693.76516    1681.458
# 76           Europe and Central Asia         A   21436.7762    20984.78
# 77                Sub-Saharan Africa         A     619574.5    500789.6
# 78           Europe and Central Asia         A    934.74327    898.3296
# 79           Europe and Central Asia         A    89.532842    88.33066
# 80   Latin America and the Caribbean         B    511.34711    487.6984
# 81                               NaN         A    205.41507    194.2904
# 82   Latin America and the Caribbean         B    38238.004    31371.62
# 83                Sub-Saharan Africa         A    283675.07    235195.1
# 84                Sub-Saharan Africa         A     98609.14    78821.69
# 85   Latin America and the Caribbean         B    22713.271    20913.44
# 86   Latin America and the Caribbean         B    356824.29    313251.6
# 87   Latin America and the Caribbean         B    30779.651    25959.27
# 88           Europe and Central Asia         A   1748.92786    1725.244
# 89           Europe and Central Asia         A    60.807529    59.17611
# 90   East, South and South-East Asia         A      6823203     5770929
# 91   East, South and South-East Asia         A    933303.21    855522.1
# 92      Middle East and North Africa         A  26412.29509    26382.84
# 93      Middle East and North Africa         A      6002.31    4860.863
# 94           Europe and Central Asia         A    664.84509    642.5257
# 95      Middle East and North Africa         A    1917.3626    1712.951
# 96           Europe and Central Asia         A   35146.0227    34549.22
# 97   Latin America and the Caribbean         B  18149.01496    18077.68
# 98   East, South and South-East Asia         A    6480.2272    5784.242
# 99      Middle East and North Africa         A     604.5573    500.7603
# 100          Europe and Central Asia         A   17870.2753    16929.48
# 101               Sub-Saharan Africa         A    3104198.3     2110755
# 102                          Oceania         A    28.231083    25.42931
# 103     Middle East and North Africa         A     347.8623    201.3337
# 104          Europe and Central Asia         A   13953.0841    13823.43
# 105  East, South and South-East Asia         A            0           0
# 106          Europe and Central Asia         A   5393.93527    5342.366
# 107     Middle East and North Africa         A    4061.8478    3875.685
# 108               Sub-Saharan Africa         A     733974.3    579343.1
# 109               Sub-Saharan Africa         A    116441.79    97314.25
# 110               Sub-Saharan Africa         A    5486.9814    4868.105
# 111          Europe and Central Asia         A   3008.22704     2967.91
# 112          Europe and Central Asia         A   138.645097    136.2802
# 113               Sub-Saharan Africa         A    226513.31    179911.8
# 114               Sub-Saharan Africa         A    1723555.3     1189228
# 115  East, South and South-East Asia         A   103087.568    101295.6
# 116  East, South and South-East Asia         A    52.295784    42.83203
# 117               Sub-Saharan Africa         A     386669.7    280360.6
# 118          Europe and Central Asia         A    93.870111    91.83197
# 119                          Oceania         A    170.99646     145.303
# 120               Sub-Saharan Africa         A    18990.257    14965.87
# 121               Sub-Saharan Africa         A    3872.0935     3714.38
# 122  Latin America and the Caribbean         B    258597.16    244776.9
# 123                          Oceania         A            0           0
# 124                              NaN         A            0           0
# 125  East, South and South-East Asia         A   160.285481    152.2821
# 126          Europe and Central Asia         A     61.82467    60.08948
# 127                              NaN         B            0           0
# 128     Middle East and North Africa         A    17375.661    16281.27
# 129               Sub-Saharan Africa         A      4241733     2769133
# 130  East, South and South-East Asia         A    393499.72    382019.7
# 131               Sub-Saharan Africa         A    297031.57    240660.4
# 132                          Oceania         A            0           0
# 133  East, South and South-East Asia         A    90026.449    83510.78
# 134          Europe and Central Asia         A    3232.7088    3127.204
# 135                              NaN         A            0           0
# 136                              NaN         A    628.40143    607.3335
# 137  Latin America and the Caribbean         B    9753.1584    9524.273
# 138               Sub-Saharan Africa         A    195978.98    135371.9
# 139               Sub-Saharan Africa         A      7887547     5694592
# 140                          Oceania         A            0           0
# 141                              NaN         A    69.205369    66.76201
# 142          Europe and Central Asia         A    699.33402    678.3519
# 143     Middle East and North Africa         A   3404.10173    3332.475
# 144  East, South and South-East Asia         A     78120.91    67978.19
# 145                          Oceania         A            0           0
# 146  Latin America and the Caribbean         B   23247.4203    23000.54
# 147                          Oceania         A    43382.944    39671.85
# 148  Latin America and the Caribbean         B   17659.2766    16829.96
# 149  Latin America and the Caribbean         B   42538.8981    41977.43
# 150  East, South and South-East Asia         A    219807.38    171126.2
# 151          Europe and Central Asia         A    7167.1877    6596.052
# 152          Europe and Central Asia         A   31209.4379    30996.17
# 153                              NaN         B   12713.3957    12482.09
# 154                              NaN         A   346.507804    336.5839
# 155                              NaN         A            0           0
# 156          Europe and Central Asia         A            0           0
# 157          Europe and Central Asia         A    5167.9248     4608.22
# 158          Europe and Central Asia         A    988825.31    948880.7
# 159               Sub-Saharan Africa         A    275603.83    197362.9
# 160  Latin America and the Caribbean         B            0           0
# 161  Latin America and the Caribbean         B    439.95915    412.1581
# 162  Latin America and the Caribbean         B    944.46049    888.0634
# 163                          Oceania         A    407.22978    339.6084
# 164          Europe and Central Asia         A            0           0
# 165               Sub-Saharan Africa         A     22.97854    21.51168
# 166     Middle East and North Africa         A    24373.227    22159.24
# 167               Sub-Saharan Africa         A    134448.76    101581.2
# 168          Europe and Central Asia         A   2238.15645     2154.67
# 169               Sub-Saharan Africa         A    257.16646     241.507
# 170               Sub-Saharan Africa         A    152842.72    128471.3
# 171  East, South and South-East Asia         A    650.56364    630.0973
# 172                              NaN         B            0           0
# 173          Europe and Central Asia         A   266.523484    266.3305
# 174          Europe and Central Asia         A    83.003198    75.85926
# 175                          Oceania         A    1302.3891    1064.898
# 176               Sub-Saharan Africa         A     92811.29    60049.43
# 177               Sub-Saharan Africa         A      9101345     7063812
# 178               Sub-Saharan Africa         A    485667.69    390553.6
# 179                              NaN         A   44345.0454    43690.42
# 180  East, South and South-East Asia         A    2672.6361     2442.16
# 181                              NaN         A    221104.87    199167.1
# 182  Latin America and the Caribbean         B    6288.2795    6141.119
# 183               Sub-Saharan Africa         A    352656.93    280416.9
# 184          Europe and Central Asia         A    1205.8183    1166.964
# 185          Europe and Central Asia         A   2685.55472    2623.446
# 186     Middle East and North Africa         A            0           0
# 187          Europe and Central Asia         A    8972.2729    8162.652
# 188               Sub-Saharan Africa         A    2700468.6     2157596
# 189  East, South and South-East Asia         A   618690.504    617388.6
# 190          Europe and Central Asia         A            0           0
# 191  East, South and South-East Asia         A    3324.5304    2800.047
# 192               Sub-Saharan Africa         A    333705.77    270540.8
# 193                              NaN         A            0           0
# 194                          Oceania         A     70.98323    58.53044
# 195                              NaN         B   10906.3897    10470.87
# 196     Middle East and North Africa         A    4388.2832    4206.569
# 197          Europe and Central Asia         A     9611.373    8426.082
# 198          Europe and Central Asia         A   17007.7611    16269.72
# 199                              NaN         B            0           0
# 200                          Oceania         A            0           0
# 201               Sub-Saharan Africa         A    2135621.7     1704291
# 202          Europe and Central Asia         A   372178.135    368306.8
# 203                              NaN         A   13202.4433    12903.31
# 204          Europe and Central Asia         A            0           0
# 205                              NaN         B   360805.201    354844.3
# 206  Latin America and the Caribbean         B    7386.9313    7240.112
# 207                              NaN         B            0           0
# 208          Europe and Central Asia         A   25773.3155    25647.92
# 209                          Oceania         A    616.84929    521.5702
# 210  Latin America and the Caribbean         B   101078.988    96054.95
# 211  East, South and South-East Asia         A            0           0
# 212                              NaN         A            0           0
# 213     Middle East and North Africa         A            0           0
# 214     Middle East and North Africa         A    8187.5502    7299.473
# 215               Sub-Saharan Africa         A    2027191.3     1156376
# 216               Sub-Saharan Africa         A    2526567.3     1902673
# 217                              NaN       NaN          NaN         NaN
# 218                              NaN       NaN          NaN         NaN
# 219                              NaN       NaN          NaN         NaN
# 220                              NaN       NaN          NaN         NaN
# 221                              NaN       NaN          NaN         NaN
# 222                              NaN       NaN          NaN         NaN
# 223                              NaN       NaN          NaN         NaN
# 224                              NaN       NaN          NaN         NaN
# 225                              NaN       NaN          NaN         NaN
# 226                              NaN       NaN          NaN         NaN
# 227                              NaN       NaN          NaN         NaN
# 228                              NaN       NaN          NaN         NaN
# 229                              NaN       NaN          NaN         NaN
# 230                              NaN       NaN          NaN         NaN
# 231                              NaN       NaN          NaN         NaN
# 232                              NaN       NaN          NaN         NaN
# 233                              NaN       NaN          NaN         NaN
#
# ...
# 6                        0.000000                          0.000000
# 7                        0.012972                          3.179284
# 8                       51.636571                      14427.796753
# 9                        0.096806                         23.340979
# 10                       0.000000                          0.000000
# 11                       0.387196                        107.443596
# 12                       0.000000                          0.000000
# 13                       0.401616                        100.398887
# 14                       0.000000                          0.000000
# 15                       0.596887                        146.293620
# 16                       1.291012                        359.576862
# 17                       0.270000                         66.886023
# 18                       2.127859                        513.910474
# 19                       0.000000                          0.000000
# 20                       0.191443                         54.435811
# 21                       4.608272                       1442.041027
# 22                       0.013770                          3.374850
# 23                       0.016275                          3.919130
# 24                       0.147510                         36.153897
# 25                       0.000000                          0.000000
# 26                       0.000000                          0.000000
# 27                      29.507192                       8756.172910
# 28                     369.734261                      99735.020687
# 29                       0.000000                          0.000000
# 30                       0.000000                          0.000000
# 31                       0.000000                          0.000000
# 32                       6.797115                       2054.012029
# 33                      27.099456                       8043.914012
# 34                      58.664572                      15313.247530
# 35                     531.525868                     142423.940310
# 36                       0.536744                        131.553037
# 37                       0.223954                         54.889801
# 38                       0.000000                          0.000000
# 39                       8.358893                       2315.481268
# 40                      12.626115                       3670.941423
# 41                       1.780228                        475.603204
# 42                     188.278886                      45338.280942
# 43                       0.000000                          0.000000
# 44                       0.000000                          0.000000
# 45                     114.830534                      31424.274829
# 46                       0.028842                          7.062985
# 47                       6.696798                       1639.941331
# 48                       0.000000                          0.000000
# 49                       0.356419                         95.395064
# 50                     274.000599                      77917.189352
# 51                       0.000000                          0.000000
# 52                       1.353845                        372.625111
# 53                       0.000000                          0.000000
# 54                       0.000000                          0.000000
# 55                       0.021642                          5.304355
# 56                       0.000000                          0.000000
# 57                     219.199583                      65209.449124
# 58                       0.000000                          0.000000
# 59                       1.611823                        413.021549
# 60                       0.026619                          7.284469
# 61                       6.625582                       1743.311314
# 62                       1.833115                        469.163046
# 63                       1.119222                        340.621834
# 64                       7.185528                       1899.105349
# 65                       1.012821                        265.132360
# 66                      13.669899                       4215.836531
# 67                       0.000000                          0.000000
# 68                      40.362596                       9884.170094
# 69                       0.504399                        123.625232
# 70                       0.000000                          0.000000
# 71                       0.000000                          0.000000
# 72                       0.000000                          0.000000
# 73                       3.175745                        840.357285
# 74                       0.000000                          0.000000
# 75                       0.276166                         68.757664
# 76                       0.000000                          0.000000
# 77                      15.622347                       4460.741348
# 78                       0.000000                          0.000000
# 79                       0.002948                          0.722533
# 80                       0.674426                        184.562085
# 81                       0.006484                          1.589271
# 82                       3.320720                       1048.038664
# 83                       6.256876                       1728.555108
# 84                       2.591779                        634.686331
# 85                       8.716669                       2527.000010
# 86                      14.955461                       4024.957662
# 87                       7.366851                       2325.235312
# 88                       0.000000                          0.000000
# 89                       0.000000                          0.000000
# 90                     227.757015                      56421.352376
# 91                       7.058006                       1903.599130
# 92                       0.880511                        215.808255
# 93                       0.000000                          0.000000
# 94                       0.000000                          0.000000
# 95                       0.000000                          0.000000
# 96                       0.000000                          0.000000
# 97                       7.887287                       1948.149934
# 98                       0.133592                         32.169419
# 99                       0.000000                          0.000000
# 100                      3.665053                       1069.014579
# 101                    759.790479                     300516.682161
# 102                      0.003264                          0.800033
# 103                      0.000000                          0.000000
# 104                      2.766414                        691.351032
# 105                      0.000000                          0.000000
# 106                      0.097983                         24.559561
# 107                      0.368074                         90.303507
# 108                     22.331944                       7376.521189
# 109                      2.142092                        552.203577
# 110                      0.160071                         39.198851
# 111                      0.000000                          0.000000
# 112                      0.000000                          0.000000
# 113                      3.459046                        867.920419
# 114                    559.099347                     201903.298336
# 115                      4.548495                       1170.205546
# 116                      0.000989                          0.238213
# 117                      7.200955                       2230.560734
# 118                      0.000000                          0.000000
# 119                      0.020347                          4.986965
# 120                      2.245615                        628.109583
# 121                      0.105636                         25.670754
# 122                     69.560726                      19315.968289
# 123                      0.000000                          0.000000
# 124                      0.000000                          0.000000
# 125                      0.008794                          2.156833
# 126                      0.000000                          0.000000
# 127                      0.000000                          0.000000
# 128                      3.479021                       1007.609059
# 129                   1601.960884                     617464.514005
# 130                     86.443255                      22564.547424
# 131                     80.012401                      27317.477087
# 132                      0.000000                          0.000000
# 133                      2.375023                        658.399839
# 134                      0.000000                          0.000000
# 135                      0.000000                          0.000000
# 136                      0.020269                          4.967910
# 137                      2.181605                        558.248945
# 138                     37.250539                      11189.279532
# 139                    187.247011                      45853.872208
# 140                      0.000000                          0.000000
# 141                      0.002228                          0.546105
# 142                      0.000000                          0.000000
# 143                      0.000000                          0.000000
# 144                      0.373836                         97.234096
# 145                      0.000000                          0.000000
# 146                      1.267424                        328.254495
# 147                      6.750122                       1795.721391
# 148                      3.681841                        974.272129
# 149                     14.340336                       3701.162587
# 150                     14.818805                       3910.734981
# 151                      0.000000                          0.000000
# 152                      0.000000                          0.000000
# 153                      0.416582                        102.101899
# 154                      0.011233                          2.753213
# 155                      0.000000                          0.000000
# 156                      0.000000                          0.000000
# 157                      0.000000                          0.000000
# 158                     31.668305                       7761.722703
# 159                     45.093032                      15940.495700
# 160                      0.000000                          0.000000
# 161                      0.437414                        119.701745
# 162                      0.081682                         22.352840
# 163                      0.011334                          2.777953
# 164                      0.000000                          0.000000
# 165                      0.009398                          2.301470
# 166                      0.000000                          0.000000
# 167                     29.987772                       8719.106767
# 168                      0.000000                          0.000000
# 169                      0.133278                         32.637609
# 170                      3.181770                        830.529444
# 171                      0.035618                          8.577019
# 172                      0.000000                          0.000000
# 173                      0.000000                          0.000000
# 174                      0.000000                          0.000000
# 175                      0.211254                         51.777063
# 176                      2.925355                        854.248317
# 177                    311.256776                     111382.383454
# 178                     33.049058                       8558.970273
# 179                     91.410044                      24311.352807
# 180                      0.267796                         77.847110
# 181                      1.460494                        389.756815
# 182                      0.310143                         81.656476
# 183                     24.138980                       8000.522656
# 184                      0.000000                          0.000000
# 185                      0.000000                          0.000000
# 186                      0.000000                          0.000000
# 187                      0.895078                        327.461947
# 188                     72.008429                      17648.859183
# 189                    167.557109                      43192.486258
# 190                      0.000000                          0.000000
# 191                      0.064669                         15.572634
# 192                     10.179861                       2952.438051
# 193                      0.000000                          0.000000
# 194                      0.001953                          0.478772
# 195                      2.084843                        567.102188
# 196                      0.793331                        191.880813
# 197                      0.000000                          0.000000
# 198                      0.000000                          0.000000
# 199                      0.000000                          0.000000
# 200                      0.000000                          0.000000
# 201                    686.213605                     219418.568093
# 202                     46.306811                      11518.011669
# 203                      0.430640                        105.547425
# 204                      0.000000                          0.000000
# 205                     11.842709                       2902.580966
# 206                      0.398960                        104.942110
# 207                      0.000000                          0.000000
# 208                      3.291965                        821.363024
# 209                      0.261715                         64.144836
# 210                      3.205774                        785.717199
# 211                      0.000000                          0.000000
# 212                      0.000000                          0.000000
# 213                      0.000000                          0.000000
# 214                      0.100389                         29.581118
# 215                    163.776965                      70084.531962
# 216                    530.374765                     190929.633661
# 217                      0.000000                          0.000000
# 218                      0.000000                          0.000000
# 219                      0.000000                          0.000000
# 220                      0.000000                          0.000000
# 221                      0.000000                          0.000000
# 222                      0.000000                          0.000000
# 223                      0.000000                          0.000000
# 224                      0.000000                          0.000000
# 225                      0.000000                          0.000000
# 226                      0.000000                          0.000000
# 227                      0.000000                          0.000000
# 228                      0.000000                          0.000000
# 229                      0.000000                          0.000000
# 230                      0.000000                          0.000000
# 231                      0.000000                          0.000000
# 232                      0.000000                          0.000000
# 233                      0.000000                          0.000000
#
# [234 rows x 96 columns]

# %% [markdown]
# ## Export to CSV

# %%
main_df.to_csv("impact_score.csv", index=False)
print("File saved as impact_score.csv")
# Out:
# File saved as impact_score.csv
